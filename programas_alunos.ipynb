# %% [markdown]
# <a href="https://colab.research.google.com/github/Rubmara/exercicios_multidisciplinares/blob/main/programas_alunos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Banco de dados com categorias, animais e dicas
categorias = {
    "Domésticos": {
        "gato": [
            "Sou um mestre do sono, posso dormir até 18 horas por dia.",
            "Meu ronronar é mágico, relaxa até as pessoas estressadas.",
            "Tenho um temperamento misterioso e adoro janelas para observar o mundo."
        ],
        "cachorro": [
            "Sou o melhor amigo do homem e adoro brincar na água.",
            "Tenho um coração enorme e gosto de lamber todo mundo.",
            "Se você me chamar para correr, vou ser o primeiro a chegar!"
        ],
        "hamster": [
            "Eu sou pequenino e super energético, mas sempre me escondo nas minhas casinhas.",
            "Tenho um estoque secreto de comida nas bochechas.",
            "Adoro correr em rodas como se estivesse em uma maratona!"
        ]
    },
    "Selvagens": {
        "leão": [
            "Sou o rei da selva e meu rugido pode ser ouvido a quilômetros.",
            "A minha juba é digna de um tapete real.",
            "Eu durmo até 20 horas por dia... é muito difícil ser um rei!"
        ],
        "elefante": [
            "Sou o maior animal terrestre e tenho uma memória fantástica!",
            "Minha tromba serve para pegar coisas, como um grande aspirador.",
            "Costumo dar grandes abraços com a minha tromba, é como um abraço de 100kg!"
        ],
        "tigre": [
            "Minhas listras são únicas, como a minha assinatura!",
            "Sou um predador solitário, mas eu sempre arraso quando caço.",
            "Meu rugido é tão poderoso, que as árvores balançam quando eu falo!"
        ]
    },
    "Aquáticos": {
        "golfinho": [
            "Eu sou um showman! Adoro saltar e fazer acrobacias.",
            "Sou um dos animais mais inteligentes do planeta.",
            "Eu me comunico com meus amigos em 'delfinês', é quase como uma língua secreta!"
        ],
        "tubarão": [
            "Meus dentes são afiados como facas, mas não sou tão malvado quanto me pintam!",
            "Adoro nadar no fundo do oceano, como se fosse um super-herói marinho.",
            "Eu não gosto de gritos... se você me ver, melhor manter a calma!"
        ],
        "baleia": [
            "Eu sou tão grande que sou o maior animal do planeta!",
            "Costumo cantar músicas profundas, e elas podem ser ouvidas a quilômetros.",
            "Minha barriga é como um aquário em miniatura, cheia de criaturas do mar!"
        ]
    },
    "Aéreos": {
        "papagaio": [
            "Tenho penas coloridas e sou um verdadeiro imitador, posso imitar vozes humanas!",
            "Adoro viver nas florestas tropicais e sempre estou em busca de aventuras.",
            "Meu bico é super afiado, mas não sou tão malvado quanto pareço."
        ],
        "pinguim": [
            "Sou um ótimo nadador, mas minha habilidade de voar é... bem... limitada!",
            "Eu ando de forma engraçada, é como se estivesse desfilando no tapete vermelho.",
            "Quando estou frio, me aconchego com os amigos, como uma grande festa no gelo!"
        ]
    },
    "Mistura Maluca": {
        "dragão": [
            "Sou uma criatura mitológica e posso voar! Mas, cuidado... tenho fogo na boca!",
            "Minhas escamas brilhantes são impenetráveis, sou como uma armadura ambulante.",
            "Eu vivo em cavernas e gosto de colecionar tesouros. Se você me encontrar, traga ouro!"
        ],
        "unicórnio": [
            "Eu sou a definição de magia! Meu chifre tem poderes curativos.",
            "Adoro correr por campos de flores, espalhando arco-íris por onde passo.",
            "Sou muito raro, mas se você me ver, é porque você é especial!"
        ]
    },
    "Mitos e Lendas": {
        "quimera": [
            "Sou metade leão, metade cabra e um pouco de serpente. Meus superpoderes são épicos!",
            "Meu rugido é como o trovão e posso lançar fogo pelo meu corpo.",
            "Eu sou uma criatura mitológica, então você só me verá se for muito corajoso!"
        ],
        "fênix": [
            "Eu sou a ave que renasce das cinzas, como se fosse mágica!",
            "Meu canto pode curar corações partidos e trazer boa sorte.",
            "Quando morro, fico em chamas e depois volto mais forte do que nunca!"
        ]
    }
}

# Função para uma rodada do jogo
def rodada(categoria, animal, dicas, tentativas):
    print(f"\nCategoria: {categoria}")
    print(f"Você tem {tentativas} tentativas para adivinhar.\n")
    for tentativa in range(tentativas):
        print(f"Dica {tentativa + 1}: {dicas[tentativa]}")
        resposta = input("Qual é o animal? ").strip().lower()
        if resposta == animal:
            print(f"🎉 Parabéns! Você acertou, é um {animal.upper()}! 🐾")
            return True
        else:
            print("🤔 Não é esse animal. Tente novamente!\n")
    print(f"💔 Que pena! O animal era um {animal.upper()}.")
    return False

# Função principal para o jogo
def jogo_adivinhe_o_animal():
    print("🎮 Bem-vindo ao jogo *Adivinhe o Animal*! 🐾")
    print("\n🎯 Objetivo do jogo:")
    print("Você deve adivinhar o animal com base nas dicas fornecidas. O jogo é dividido em fases, e cada categoria tem um conjunto de animais para você descobrir.")
    print("\n📋 Regras e Pontuação:")
    print("1. Cada categoria contém várias fases com diferentes animais.")
    print("2. Você tem até 3 tentativas para cada animal. As dicas ficam mais difíceis conforme avança.")
    print("3. Cada acerto vale 10 pontos por fase.")
    print("4. O total de pontos possível depende do número de animais em cada categoria.")
    print("\nBoa sorte! 🌟 Vamos começar!\n")

    categorias_lista = list(categorias.keys())
    pontos = 0
    total_animais = sum(len(categorias[categoria]) for categoria in categorias_lista)
    total_pontos_possiveis = total_animais * 10

    print(f"O jogo tem um total de {total_animais} perguntas e você pode marcar até {total_pontos_possiveis} pontos!\n")

    # Loop pelas categorias
    for categoria in categorias_lista:
        print(f"\n{'='*40}")
        print(f"Categoria: {categoria.upper()}")
        print(f"{'='*40}")
        animais = list(categorias[categoria].items())
        random.shuffle(animais)

        # Loop pelas fases
        for fase, (animal, dicas) in enumerate(animais, start=1):
            tentativas = max(3 - fase, 1)  # Menos tentativas nas fases avançadas
            print(f"\n--- Fase {fase} ---")
            venceu = rodada(categoria, animal, dicas, tentativas)
            if venceu:
                pontos += 10  # Correção: pontuação fixa por acerto
            else:
                print("Você perdeu essa fase. Vamos continuar!")

    print("\n🏆 Jogo Finalizado! 🏆")
    print(f"Seu total de pontos: {pontos}")
    print(f"Pontos máximos possíveis: {total_pontos_possiveis}")

    # Perguntar se o jogador quer jogar novamente
    jogar_novamente = input("\nQuer jogar novamente? (sim/não): ").strip().lower()
    if jogar_novamente == "sim":
        jogo_adivinhe_o_animal()
    else:
        print("Obrigado por jogar! Até a próxima! 🐾")

# Iniciar o jogo
jogo_adivinhe_o_animal()

# %%
# Lista de livros ampliada com muitos gêneros e títulos
livros = [
    {"titulo": "O Senhor dos Anéis", "autor": "J.R.R. Tolkien", "genero": "Fantasia"},
    {"titulo": "1984", "autor": "George Orwell", "genero": "Distopia"},
    {"titulo": "O Hobbit", "autor": "J.R.R. Tolkien", "genero": "Fantasia"},
    {"titulo": "Harry Potter e a Pedra Filosofal", "autor": "J.K. Rowling", "genero": "Fantasia"},
    {"titulo": "Orgulho e Preconceito", "autor": "Jane Austen", "genero": "Romance"},
    {"titulo": "A Revolução dos Bichos", "autor": "George Orwell", "genero": "Distopia"},
    {"titulo": "O Grande Gatsby", "autor": "F. Scott Fitzgerald", "genero": "Romance"},
    {"titulo": "A Guerra dos Tronos", "autor": "George R.R. Martin", "genero": "Fantasia"},
    {"titulo": "O Código Da Vinci", "autor": "Dan Brown", "genero": "Mistério"},
    {"titulo": "Cem Anos de Solidão", "autor": "Gabriel García Márquez", "genero": "Realismo Mágico"},
    {"titulo": "O Morro dos Ventos Uivantes", "autor": "Emily Brontë", "genero": "Romance"},
    {"titulo": "Neuromancer", "autor": "William Gibson", "genero": "Ficção Científica"},
    {"titulo": "O Guia do Mochileiro das Galáxias", "autor": "Douglas Adams", "genero": "Ficção Científica"},
    {"titulo": "Sherlock Holmes: Um Estudo em Vermelho", "autor": "Arthur Conan Doyle", "genero": "Mistério"},
    {"titulo": "A Menina que Roubava Livros", "autor": "Markus Zusak", "genero": "Drama"},
    {"titulo": "As Crônicas de Nárnia", "autor": "C.S. Lewis", "genero": "Fantasia"},
    {"titulo": "O Pintassilgo", "autor": "Donna Tartt", "genero": "Drama"},
    {"titulo": "A Caverna", "autor": "José Saramago", "genero": "Filosofia"},
    {"titulo": "Fahrenheit 451", "autor": "Ray Bradbury", "genero": "Distopia"},
    {"titulo": "O Sol é para Todos", "autor": "Harper Lee", "genero": "Drama"},
    {"titulo": "O Processo", "autor": "Franz Kafka", "genero": "Ficção Filosófica"},
    {"titulo": "A Divina Comédia", "autor": "Dante Alighieri", "genero": "Poesia"},
    {"titulo": "Dom Quixote", "autor": "Miguel de Cervantes", "genero": "Aventura"},
    {"titulo": "Drácula", "autor": "Bram Stoker", "genero": "Terror"},
    {"titulo": "O Nome da Rosa", "autor": "Umberto Eco", "genero": "Mistério"},
    {"titulo": "O Retrato de Dorian Gray", "autor": "Oscar Wilde", "genero": "Romance Gótico"},
    {"titulo": "A Ilha do Tesouro", "autor": "Robert Louis Stevenson", "genero": "Aventura"},
    {"titulo": "O Estrangeiro", "autor": "Albert Camus", "genero": "Filosofia"},
    {"titulo": "Os Miseráveis", "autor": "Victor Hugo", "genero": "Drama Histórico"},
    {"titulo": "O Silêncio dos Inocentes", "autor": "Thomas Harris", "genero": "Suspense, Thriller"},
    {"titulo": "O Assassinato de Roger Ackroyd", "autor": "Agatha Christie", "genero": "Mistério, Suspense"},
    {"titulo": "O Conto da Aia", "autor": "Margaret Atwood", "genero": "Distopia"},
    {"titulo": "Duna", "autor": "Frank Herbert", "genero": "Ficção Científica"},
    {"titulo": "It: A Coisa", "autor": "Stephen King", "genero": "Terror"},
    {"titulo": "Belas Maldições", "autor": "Neil Gaiman e Terry Pratchett", "genero": "Fantasia, Humor"},
    {"titulo": "A Sombra do Vento", "autor": "Carlos Ruiz Zafón", "genero": "Mistério"},
    {"titulo": "A Torre Negra", "autor": "Stephen King", "genero": "Fantasia, Terror"},
    {"titulo": "O Senhor das Moscas", "autor": "William Golding", "genero": "Distopia"},
    {"titulo": "Os Três Mosqueteiros", "autor": "Alexandre Dumas", "genero": "Aventura"},
    {"titulo": "Bonequinha de Luxo", "autor": "Truman Capote", "genero": "Drama"},
    {"titulo": "O Livro do Desassossego", "autor": "Fernando Pessoa", "genero": "Filosofia, Poesia"}
]

# Gêneros disponíveis
generos_disponiveis = [
    "Fantasia", "Distopia", "Romance", "Mistério", "Realismo Mágico",
    "Ficção Científica", "Drama", "Filosofia", "Aventura", "Poesia",
    "Terror", "Filosofia Política", "Romance Gótico", "Ficção Filosófica",
    "Histórico", "Suspense", "Thriller"
]

# Função para sugerir livros com base no gênero
def sugerir_livros(generos_escolhidos):
    livros_sugeridos = [
        livro for livro in livros if any(
            gen.lower() in livro["genero"].lower() for gen in generos_escolhidos
        )
    ]

    if livros_sugeridos:
        print("\nSugestões de livros para os gêneros escolhidos:")
        for livro in livros_sugeridos:
            print(f"- {livro['titulo']} por {livro['autor']} ({livro['genero']})")
    else:
        print("\nDesculpe, não encontramos livros para o(s) gênero(s) solicitado(s). Tente outros gêneros.")

# Função principal
def main():
    print("🎉 Bem-vindo ao sistema de sugestões de livros! 📚")
    print("\n📝 Gêneros disponíveis:")
    print(", ".join(generos_disponiveis))

    print("\n🔢 Você pode inserir até 3 gêneros. Por favor, separe-os por vírgulas.")

    # Solicitar os gêneros ao usuário
    generos_entrada = input("Quais gêneros de livro você prefere? ").strip()

    # Converter entrada em uma lista e validar o limite
    generos_escolhidos = [gen.strip().capitalize() for gen in generos_entrada.split(",")]
    if len(generos_escolhidos) > 3:
        print("\n⚠️ Você inseriu mais de 3 gêneros! Por favor, escolha até 3 gêneros e tente novamente.")
        return

    # Sugerir livros com base nos gêneros informados
    sugerir_livros(generos_escolhidos)

# Executar o programa
if __name__ == "__main__":
    main()

# %%
import pandas as pd
from datetime import datetime

# Lista de atividades pré-definidas
atividades_possiveis = [
    "Prova de Matemática",
    "Entrega de Trabalho de História",
    "Revisão para Prova de Física",
    "Estudo para Exame de Química",
    "Leitura de Textos de Literatura",
    "Elaboração de Resumo de Biologia"
]

# Função para exibir opções e permitir escolha ou adicionar nova atividade
def escolher_atividade():
    print("\nEscolha uma atividade para incluir na agenda:")
    for i, atividade in enumerate(atividades_possiveis, 1):
        print(f"{i}. {atividade}")
    print(f"{len(atividades_possiveis) + 1}. Outra (digite sua própria atividade)")

    while True:
        try:
            escolha = int(input("\nDigite o número da atividade que deseja escolher: "))
            if 1 <= escolha <= len(atividades_possiveis):
                return atividades_possiveis[escolha - 1]
            elif escolha == len(atividades_possiveis) + 1:
                nova_atividade = input("Digite a nova atividade: ").strip()
                if nova_atividade:
                    return nova_atividade
                else:
                    print("Atividade inválida. Tente novamente.")
            else:
                print("Número inválido. Escolha um número dentro do intervalo.")
        except ValueError:
            print("Entrada inválida. Digite um número.")

# Função para criar a agenda de tarefas
def criar_agenda_tarefas():
    # Inicializando uma lista para armazenar as tarefas
    agenda = []
    hoje = datetime.now()

    print("\nCrie sua agenda de tarefas. Quando terminar, digite 'fim'.")

    while True:
        # Solicitar a data da tarefa
        data_input = input("\nDigite a data para a tarefa (formato DD/MM/AAAA) ou 'fim' para encerrar: ").strip()
        if data_input.lower() == 'fim':
            break

        # Validar a data
        try:
            data_tarefa = datetime.strptime(data_input, "%d/%m/%Y")
        except ValueError:
            print("Data inválida. Tente novamente.")
            continue

        # Verificar se a data da tarefa é no futuro
        if data_tarefa <= hoje:
            print("A data da tarefa deve ser no futuro. Tente novamente.")
            continue

        # Escolher a atividade
        atividade = escolher_atividade()

        # Calcular dias disponíveis e sugerir horas diárias (assumindo 2 horas por dia por padrão)
        dias_disponiveis = (data_tarefa - hoje).days
        horas_por_dia = max(2, 10 // dias_disponiveis)  # Pelo menos 2 horas por dia, ajustado para até 10 horas totais

        # Adicionar a tarefa à agenda
        agenda.append({
            "Data Tarefa": data_tarefa.strftime("%d/%m/%Y"),
            "Atividade": atividade,
            "Dias Disponíveis": dias_disponiveis,
            "Horas por Dia Sugeridas": horas_por_dia
        })

    # Retornar a agenda como um DataFrame
    return pd.DataFrame(agenda)

# Criar a agenda
agenda_tarefas = criar_agenda_tarefas()

# Exibir a agenda gerada
print("\nAgenda de Tarefas:")
print(agenda_tarefas.to_string(index=False))
